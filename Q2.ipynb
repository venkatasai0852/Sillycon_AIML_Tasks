# %% [markdown]
# <a href="https://colab.research.google.com/github/venkatasai0852/Sillycon_AIML_Tasks/blob/main/Q2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing necessary python libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data loading and understanding

# %%
#loading the titanic dataset
df = pd.read_csv('titanic.csv')
df.head() #returns first 5 rows of titanic dataset
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.sample(5)  #returns random 5 rows of titanic dataset
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 290         1182         0       1  Rheims, Mr. George Alexander Lucien
# 382         1274         1       3           Risien, Mrs. Samuel (Emma)
# 23           915         0       1      Williams, Mr. Richard Norris II
# 145         1037         0       3            Vander Planke, Mr. Julius
# 352         1244         0       2                  Dibden, Mr. William
#
#         Sex   Age  SibSp  Parch        Ticket     Fare Cabin Embarked
# 290    male   NaN      0      0      PC 17607  39.6000   NaN        S
# 382  female   NaN      0      0        364498  14.5000   NaN        S
# 23     male  21.0      0      1      PC 17597  61.3792   NaN        C
# 145    male  31.0      3      0        345763  18.0000   NaN        S
# 352    male  18.0      0      0  S.O.C. 14879  73.5000   NaN        S

# %%
df.shape  #returns number of rows , number of columns
# Out:
# (418, 12)

# %%
df.size  #returns number of rows * number of columns
# Out:
# 5016

# %%
df.info()  ##returns number of non-null values and data type of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.isnull().sum()  #returns number of null values in each column
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.describe()  #returns statistical summary of numerical columns
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.duplicated().sum()   #returns number of rows that are having same values in all columns
# Out:
# np.int64(0)

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# Categorical data

# %%
sns.countplot(x = df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Nearly 36 percent of passengers survived

# %%
sns.countplot(x = df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# There were more number of people in class 3 followeed by class 1 and 2 respectively

# %%
sns.countplot(x = df['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# There were more number of male passengers than female passengers

# %%
sns.countplot(x = df['SibSp'])
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
df['SibSp'].value_counts().plot(kind='pie',autopct='%.2f', )
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Nearly 67 percent people travelled without sibling and apouse

# %%
sns.countplot(x = df['Parch'])
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
df['Parch'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(x = df['Embarked'])
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Numerical data

# %%
plt.hist(x = df['Age'],bins=15)
# Out:
# (array([12., 10., 10., 37., 73., 58., 27., 29., 24., 21., 12.,  9.,  8.,
#          1.,  1.]),
#  array([ 0.17      ,  5.22533333, 10.28066667, 15.336     , 20.39133333,
#         25.44666667, 30.502     , 35.55733333, 40.61266667, 45.668     ,
#         50.72333333, 55.77866667, 60.834     , 65.88933333, 70.94466667,
#         76.        ]),
#  <BarContainer object of 15 artists>)

# %%
sns.displot(x = df['Age'])

# %%
sns.boxplot(x = df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
plt.hist(x = df['Fare'],bins=10)
# Out:
# (array([338.,  48.,  11.,   2.,  10.,   7.,   0.,   0.,   0.,   1.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(x = df['Fare'])

# %%
sns.boxplot(x = df['Fare'])
# Out:
# <Axes: xlabel='Fare'>

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# Categorical v/s Categorical

# %%
sns.heatmap(pd.crosstab(df['Pclass'],df['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %% [markdown]
# less people travelled in class 1, hence less people than class 3 survived as many people travelled in class 3 almost 50 percent

# %%
sns.clustermap(pd.crosstab(df['Pclass'],df['Survived']))

# %%
sns.heatmap(pd.crosstab(df['Sex'],df['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Sex'>

# %% [markdown]
# More females survived than males

# %%
sns.clustermap(pd.crosstab(df['Sex'],df['Survived']))

# %%
sns.heatmap(pd.crosstab(df['Embarked'],df['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Embarked'>

# %%
sns.clustermap(pd.crosstab(df['Embarked'],df['Survived']))

# %% [markdown]
# Numerical v/s Categorical

# %%
sns.barplot(x = df['Survived'],y = df['Age'])
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.boxplot(x = df['Sex'],y = df['Age'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.distplot(df[df['Survived']==0]['Age'],hist=False)
sns.distplot(df[df['Survived']==1]['Age'],hist=False)
# Out:
# /tmp/ipython-input-42-455601345.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==0]['Age'],hist=False)
# /tmp/ipython-input-42-455601345.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# Numerical v/s Numerical

# %%
sns.scatterplot(x = df['Age'],y = df['Fare'],hue = df['Sex'])
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %% [markdown]
# This is a supervised learning problem as the output is given in the dataset.
# Output is whether the passenger had survived or not.
# Hence, classification algorithm is best suited as output is either 0 or 1.
# Logistic regression can be used as it divides the plane into 2 divisions survived(1) and not survived(0).
